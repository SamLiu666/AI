# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# plt.show(): 一个循环，输出所有的表，当前坐标系画图
#
# %matplotlib -  在python环境中，声明matplot环境
#
# %matplotlib notebook - 可以在图中生成交互式图
# %matplotlib inline - 静态图片的嵌入

# %%
x1 = np.linspace(0, 10, 100)


# create a plot figure
fig = plt.figure()

plt.plot(x1, np.sin(x1), '-')
plt.plot(x1, np.cos(x1), '--');

# %% [markdown]
# Matplotlib.pyplot : 提供了一个MATLAB 风格视图的接口
# - plt.gcf ( ) # get current figure
# - plt.gca ( ) # get current axes

# %%
# create a plot figure
plt.figure()

# create the first of two panels and set current axis
plt.subplot(2, 1, 1)   # (rows, columns, panel number)
plt.plot(x1, np.sin(x1))

# create the second of two panels and set current axis
plt.subplot(2, 1, 2)   # (rows, columns, panel number)
plt.plot(x1, np.cos(x1));

# %%
print(plt.gcf())
print(plt.gca())
# Out:
# Figure(432x288)
# AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# ## Visualization with Pyplot

# %%
plt.plot([1,1,2,2])  #  两两成对(1,1)(2,2)
plt.ylabel('Numbers')
plt.show()

# %%
# 
x, y = [1,2,3,4], [2,4,6,8]

plt.plot([1,2,3,4], [1,1,1,2])
plt.plot(x,y)
plt.show()

# %% [markdown]
# ##  State-machine interface

# %%
x = np.linspace(0, 2, 100)

plt.plot(x, x, label='linear')
plt.plot(x, x**2, label='quadratic')
plt.plot(x, x**3, label='cubic')

plt.xlabel('x label')
plt.ylabel('y label')

plt.title("Simple Plot")

plt.legend()  # 图例

plt.show()

# %%
# The default format string is 'b-', which is a solid blue line. For example, to plot the above line with red circles

plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'ro')
plt.axis([0, 6, 0, 20])
plt.show()

# %% [markdown]
# # Working with NumPy arrays

# %%
# evenly sampled time at 200ms intervals
t = np.arange(0., 5., 0.2)

# red dashes, blue squares and green triangles
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()

# %% [markdown]
# # Object-Oriented API
